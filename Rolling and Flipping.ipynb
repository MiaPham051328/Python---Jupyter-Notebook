# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Random Notes:

# %%
np.random
# Out:
# <module 'numpy.random' from 'C:\\Users\\biauser\\miniconda3\\envs\\ds310\\lib\\site-packages\\numpy\\random\\__init__.py'>

# %%
np.random.rand() # return random value between >= 0 and <1
# Out:
# 0.4816199937360308

# %%
np.random.normal()
# Out:
# 1.058610429942837

# %%
st_devs = np.random.normal(0,1,1000000)
st_devs[:10]
# Out:
# array([ 1.21676776,  1.33357273,  1.00788143, -0.72929608,  0.69106513,
#         2.28277162,  0.68189858,  1.0026774 , -0.85967005, -1.77804952])

# %%
pd.DataFrame({'devs':st_devs}).plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
devs = pd.DataFrame({'devs':st_devs})
devs
# Out:
#             devs
# 0       1.216768
# 1       1.333573
# 2       1.007881
# 3      -0.729296
# 4       0.691065
# ...          ...
# 999995 -0.188881
# 999996 -0.506114
# 999997  0.129566
# 999998  0.739294
# 999999 -0.575475
#
# [1000000 rows x 1 columns]

# %%
devs.plot(kind='hist', bins=15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
devs.describe()
# Out:
#                  devs
# count  1000000.000000
# mean         0.000877
# std          0.999867
# min         -5.050374
# 25%         -0.672688
# 50%          0.001109
# 75%          0.673567
# max          4.916416

# %%
die=np.random.randint(1,7)
die
# Out:
# 3

# %%
# roll 2 dice and track your results (pur it in a list or an array...)
